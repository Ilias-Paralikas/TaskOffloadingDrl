# %%
import os
import shutil

def delete_subfolders_named_x(folder_path,dirname):
    for root, dirs, files in os.walk(folder_path, topdown=False):
        for dir_name in dirs:
            if dir_name == dirname:
                dir_path = os.path.join(root, dir_name)
                shutil.rmtree(dir_path)
                print(f"Deleted folder: {dir_path}")

# Example usage
folder_path = 'meta_plots/logs'
dirname = 'championship'
delete_subfolders_named_x(folder_path,dirname)
# Out:
# Deleted folder: meta_plots/logs\horisontal_capacities\runs\run_0\championship
# Deleted folder: meta_plots/logs\horisontal_capacities\runs\run_1\championship
# Deleted folder: meta_plots/logs\horisontal_capacities\runs\run_2\championship
# Deleted folder: meta_plots/logs\horisontal_capacities\runs\run_3\championship
# Deleted folder: meta_plots/logs\new_learning\runs\run_0\championship
# Deleted folder: meta_plots/logs\new_learning\runs\run_1\championship
# Deleted folder: meta_plots/logs\new_learning\runs\run_2\championship
# Deleted folder: meta_plots/logs\new_learning\runs\run_3\championship
# Deleted folder: meta_plots/logs\opa\runs\run_0\championship
# Deleted folder: meta_plots/logs\opa\runs\run_1\championship
# Deleted folder: meta_plots/logs\opa\runs\run_2\championship
# Deleted folder: meta_plots/logs\opa\runs\run_3\championship
# Deleted folder: meta_plots/logs\private_power\runs\0.001\championship
# Deleted folder: meta_plots/logs\private_power\runs\0.005\championship
# Deleted folder: meta_plots/logs\private_power\runs\0.015\championship
# Deleted folder: meta_plots/logs\private_power\runs\0.02\championship
# Deleted folder: meta_plots/logs\task_sizes\runs_0\run_0\championship
# Deleted folder: meta_plots/logs\task_sizes\runs_0\run_1\championship
# Deleted folder: meta_plots/logs\unknown\runs\run_0\championship
# Deleted folder: meta_plots/logs\unknown\runs\run_1\championship
# Deleted folder: meta_plots/logs\unknown\runs\run_2\championship
# Deleted folder: meta_plots/logs\unknown\runs\run_3\championship
